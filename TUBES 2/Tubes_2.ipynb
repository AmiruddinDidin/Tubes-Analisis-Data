# %% [markdown]
# ## TUBES 2

# %% [markdown]
# 1. Menampilkan dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Menampilkan Dataset
df = pd.read_csv('CAR DETAILS FROM CAR DEKHO.csv')
df
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %% [markdown]
# 2. Menampilkan 5 data awal

# %%
# Menampilkan 5 data awal
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %% [markdown]
# 3. Menampilkan 5 data akhir

# %%
# Menampilkan 5 data akhir
df.tail()
# Out:
#                                      name  year  selling_price  km_driven  \
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# 4335  Diesel  Individual       Manual  Second Owner
# 4336  Diesel  Individual       Manual  Second Owner
# 4337  Petrol  Individual       Manual  Second Owner
# 4338  Diesel  Individual       Manual   First Owner
# 4339  Petrol  Individual       Manual   First Owner

# %% [markdown]
# 4. Menampilkan mobil dengan pembelian tahun terbaru

# %%
# Mencari mobil dengan pembelian tahun terbaru

imax = df['year'].idxmax()
df[imax:imax+1]
# Out:
#                    name  year  selling_price  km_driven    fuel seller_type  \
# 158  Maruti Wagon R LXI  2020         240000     120000  Petrol  Individual
#
#     transmission        owner
# 158       Manual  First Owner

# %% [markdown]
# 5. Menampilkan mobil dengan pembelian tahun terlama

# %%
# Mencari mobil dengan pembelian tahun terlama
imin = df['year'].idxmin()
df[imin:imin+1]
# Out:
#                     name  year  selling_price  km_driven    fuel seller_type  \
# 3334  Maruti 800 AC BSII  1992          50000     100000  Petrol  Individual
#
#      transmission                 owner
# 3334       Manual  Fourth & Above Owner

# %% [markdown]
# 6. Menampilkan mobil dengan harga jual termahal

# %%
# Mencari mobil dengan harga jual termahal
imax = df['selling_price'].idxmax()
df[imax:imax+1]
# Out:
#                                           name  year  selling_price  \
# 3872  Audi RS7 2015-2019 Sportback Performance  2016        8900000
#
#       km_driven    fuel seller_type transmission        owner
# 3872      13000  Petrol      Dealer    Automatic  First Owner

# %% [markdown]
# 7. Menampilkan mobil dengan harga jual termurah

# %%
# Mencari mobil dengan harga jual termurah
imin = df['selling_price'].idxmin()
df[imin:imin+1]
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 2662  Ford Ikon 1.6 ZXI NXt  2005          20000      25000  Petrol
#
#      seller_type transmission         owner
# 2662  Individual       Manual  Second Owner

# %% [markdown]
# 8. Menampilkan mobil dengan penggunaan jarak tempuh terjauh

# %%
# Mencari mobil dengan penggunaan jarak tempuh terjauh
imax = df['km_driven'].idxmax()
df[imax:imax+1]
# Out:
#                         name  year  selling_price  km_driven    fuel  \
# 1243  Maruti Swift VXI BSIII  2009         250000     806599  Petrol
#
#      seller_type transmission        owner
# 1243      Dealer       Manual  First Owner

# %% [markdown]
# 9. Menampilkan mobil dengan penggunaan jarak tempuh terdekat

# %%
# Mencari mobil dengan penggunaan jarak tempuh terdekat
imin = df['km_driven'].idxmin()
df[imin:imin+1]
# Out:
#                     name  year  selling_price  km_driven    fuel seller_type  \
# 1312  Mahindra Quanto C6  2014         250000          1  Diesel  Individual
#
#      transmission         owner
# 1312       Manual  Second Owner

# %% [markdown]
# 10. Menampilkan statistika dataset

# %%
# Menampilkan statistika dataset
df.describe()
# Out:
#               year  selling_price      km_driven
# count  4340.000000   4.340000e+03    4340.000000
# mean   2013.090783   5.041273e+05   66215.777419
# std       4.215344   5.785487e+05   46644.102194
# min    1992.000000   2.000000e+04       1.000000
# 25%    2011.000000   2.087498e+05   35000.000000
# 50%    2014.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %% [markdown]
# 11. Mensortir data pada parameter tahun (Naik)

# %%
# Mensortir data pada parameter tahun (Naik)
df.sort_values(['year'], ascending=True)
# Out:
#                                     name  year  selling_price  km_driven  \
# 3334                  Maruti 800 AC BSII  1992          50000     100000
# 631             Maruti Gypsy E MG410W ST  1995          95000     100000
# 2972                Mahindra Jeep MM 540  1996         200000      60000
# 61              Mahindra Jeep CL 500 MDI  1996         250000      35000
# 1669            Mahindra Jeep CL 500 MDI  1997         150000     120000
# ...                                  ...   ...            ...        ...
# 2137               Maruti Ertiga 1.5 VDI  2020         550000      90000
# 1432    Hyundai Grand i10 Nios AMT Magna  2020         640000       4000
# 1774           Ford Aspire Titanium BSIV  2020         828999       1010
# 176              Maruti Alto K10 LXI CNG  2020         282000      40000
# 3933  Ford Figo Aspire 1.5 TDCi Titanium  2020         530000      45000
#
#         fuel seller_type transmission                 owner
# ...

# %% [markdown]
# 12. Mensortir data pada parameter tahun (Turun)

# %%
# Mensortir data pada parameter tahun (Turun)
df.sort_values(['year'], ascending=False)
# Out:
#                                    name  year  selling_price  km_driven  \
# 1777     Ford Ecosport 1.5 Petrol Trend  2020        1030000       1010
# 2481         Hyundai Santro Sportz BSIV  2020         520000       5000
# 1595                 Maruti Alto K10 LX  2020         250000       1100
# 2558              Maruti Swift ZXI Plus  2020         550000       5000
# 694   Hyundai Grand i10 Nios Magna CRDi  2020         700000       1400
# ...                                 ...   ...            ...        ...
# 3661                     Maruti 800 Std  1997          50000      80000
# 2972               Mahindra Jeep MM 540  1996         200000      60000
# 61             Mahindra Jeep CL 500 MDI  1996         250000      35000
# 631            Maruti Gypsy E MG410W ST  1995          95000     100000
# 3334                 Maruti 800 AC BSII  1992          50000     100000
#
#         fuel seller_type transmission                 owner
# ...

# %% [markdown]
# 13. Mensortir data pada parameter selling_price (Naik)

# %%
# Mensortir data pada parameter selling_price (Naik)
df.sort_values(['selling_price'], ascending=True)
# Out:
#                                                    name  year  selling_price  \
# 2662                              Ford Ikon 1.6 ZXI NXt  2005          20000
# 2495                                  Ford Ikon 1.4 ZXi  2000          22000
# 2444                                      Maruti 800 EX  2004          30000
# 3206                                   OpelCorsa 1.4 GL  2002          35000
# 2849                                 Tata Nano Std BSII  2009          35000
# ...                                                 ...   ...            ...
# 1023                            BMW X5 xDrive 30d xLine  2019        4950000
# 2239                            BMW X5 xDrive 30d xLine  2019        4950000
# 3969            Mercedes-Benz GLS 2016-2020 350d 4MATIC  2016        5500000
# 89    Mercedes-Benz S-Class S 350d Connoisseurs Edition  2017        8150000
# 3872           Audi RS7 2015-2019 Sportback Performance  2016        8900000
#
# ...

# %% [markdown]
# 14. Mensortir data pada parameter selling_price (Turun)

# %%
# Mensortir data pada parameter selling_price (Turun)
df.sort_values(['selling_price'], ascending=False)
# Out:
#                                                    name  year  selling_price  \
# 3872           Audi RS7 2015-2019 Sportback Performance  2016        8900000
# 89    Mercedes-Benz S-Class S 350d Connoisseurs Edition  2017        8150000
# 3969            Mercedes-Benz GLS 2016-2020 350d 4MATIC  2016        5500000
# 2258                            BMW X5 xDrive 30d xLine  2019        4950000
# 612                             BMW X5 xDrive 30d xLine  2019        4950000
# ...                                                 ...   ...            ...
# 2849                                 Tata Nano Std BSII  2009          35000
# 1832                                    Tata Nano LX SE  2012          35000
# 2444                                      Maruti 800 EX  2004          30000
# 2495                                  Ford Ikon 1.4 ZXi  2000          22000
# 2662                              Ford Ikon 1.6 ZXI NXt  2005          20000
#
# ...

# %% [markdown]
# 15. Mensortir data berdasarkan parameter km_driven (Naik)

# %%
# Mensortir data berdasarkan parameter km_driven (Naik)
df.sort_values(['km_driven'], ascending=True)
# Out:
#                                              name  year  selling_price  \
# 1312                           Mahindra Quanto C6  2014         250000
# 1715                           Ford Figo Titanium  2020         635000
# 1714               Ford Freestyle Titanium Diesel  2020         784000
# 1716            Ford Ecosport 1.5 Diesel Titanium  2020        1000000
# 1291                          Maruti Alto 800 VXI  2020         350000
# ...                                           ...   ...            ...
# 2394          Toyota Innova 2.5 V Diesel 8-seater  2009         350000
# 3679  Toyota Innova 2.5 G (Diesel) 7 Seater BS IV  2006         400000
# 4184            Maruti SX4 S Cross DDiS 320 Delta  2016         665000
# 525             Maruti SX4 S Cross DDiS 320 Delta  2016         665000
# 1243                       Maruti Swift VXI BSIII  2009         250000
#
#       km_driven    fuel seller_type transmission           owner
# ...

# %% [markdown]
# 16. Mensortir data berdasarkan parameter km_driven (Turun)

# %%
# Mensortir data berdasarkan parameter km_driven (Turun)
df.sort_values(['km_driven'], ascending=False)
# Out:
#                                              name  year  selling_price  \
# 1243                       Maruti Swift VXI BSIII  2009         250000
# 4184            Maruti SX4 S Cross DDiS 320 Delta  2016         665000
# 525             Maruti SX4 S Cross DDiS 320 Delta  2016         665000
# 3679  Toyota Innova 2.5 G (Diesel) 7 Seater BS IV  2006         400000
# 2394          Toyota Innova 2.5 V Diesel 8-seater  2009         350000
# ...                                           ...   ...            ...
# 3703          Ford EcoSport 1.5 Diesel Trend BSIV  2018         841000
# 1715                           Ford Figo Titanium  2020         635000
# 1716            Ford Ecosport 1.5 Diesel Titanium  2020        1000000
# 1714               Ford Freestyle Titanium Diesel  2020         784000
# 1312                           Mahindra Quanto C6  2014         250000
#
#       km_driven    fuel seller_type transmission           owner
# ...

# %% [markdown]
# 17. Mengklasifikasikan mobil berdasarkan tahun pembelian

# %%
# Mengklasifikasikan mobil berdasarkan tahun pembelian
df.groupby(['year','name','selling_price','km_driven','fuel','seller_type','transmission','owner']).sum()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %% [markdown]
# 18. Mengklasifikasikan mobil berdasarkan fuel (bahan bakar)

# %%
# Mengklasifikasikan mobil berdasarkan fuel (bahan bakar)
df.groupby(['fuel','name','year','selling_price','km_driven','seller_type','transmission','owner']).sum()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %% [markdown]
# 19. Mengklasifikasikan mobil berdasarkan tipe penjual (seller type)

# %%
# Mengklasifikasikan mobil berdasarkan tipe penjual (seller type)
df.groupby(['seller_type', 'name', 'year', 'selling_price', 'km_driven', 'fuel', 'transmission', 'owner']).sum()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %% [markdown]
# 20. Mengklasifikasikan mobil berdasarkan tipe transmisi

# %%
# Mengklasifikasikan mobil berdasarkan tipe transmisi
df.groupby(['transmission','name','year','selling_price','km_driven','fuel','owner','seller_type']).sum()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %% [markdown]
# 21. Mengklasifikasikan mobil berdasarkan kepemilikan (owner)

# %%
# Mengklasifikasikan mobil berdasarkan kepemilikan (owner)
df.groupby(['owner','name','year','selling_price','km_driven','fuel','transmission','seller_type']).sum()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %% [markdown]
# 22. Menghitung frekuensi penjualan mobil dalam parameter tahun

# %%
# Menghitung frekuensi penjualan mobil dalam parameter tahun
df['year'].value_counts()
# Out:
# year
# 2017    466
# 2015    421
# 2012    415
# 2013    386
# 2014    367
# 2018    366
# 2016    357
# 2011    271
# 2010    234
# 2019    195
# 2009    193
# 2008    145
# 2007    134
# 2006    110
# 2005     85
# 2020     48
# 2004     42
# 2003     23
# 2002     21
# 2001     20
# 1998     12
# 2000     12
# 1999     10
# 1997      3
# 1996      2
# 1995      1
# 1992      1
# Name: count, dtype: int64

# %% [markdown]
# 23. Menghitung frekuensi mobil berdasarkan tipe transmisi

# %%
# Menghitung frekuensi mobil berdasarkan tipe transmisi
df['transmission'].value_counts()
# Out:
# transmission
# Manual       3892
# Automatic     448
# Name: count, dtype: int64

# %% [markdown]
# 24. Menghitung frekuensi mobil berdasarkan tipe bahan bakar

# %%
# Menghitung frekuensi mobil berdasarkan tipe bahan bakar
df['fuel'].value_counts()
# Out:
# fuel
# Diesel      2153
# Petrol      2123
# CNG           40
# LPG           23
# Electric       1
# Name: count, dtype: int64

# %% [markdown]
# 25. Menghitung frekuensi mobil berdasarkan tipe kepemilikan

# %%
# Menghitung frekuensi mobil berdasarkan tipe kepemilikan
df['owner'].value_counts()
# Out:
# owner
# First Owner             2832
# Second Owner            1106
# Third Owner              304
# Fourth & Above Owner      81
# Test Drive Car            17
# Name: count, dtype: int64

# %% [markdown]
# 26. Menghitung frekuensi berdasarkan tipe penjualan

# %%
# Menghitung frekuensi berdasarkan tipe penjualan
df['seller_type'].value_counts()
# Out:
# seller_type
# Individual          3244
# Dealer               994
# Trustmark Dealer     102
# Name: count, dtype: int64

# %% [markdown]
# 27. Menampilkan mobil berbahan bakar Diesel dengan harga termahal

# %%
# Menampilkan mobil berbahan bakar Diesel termahal
Diesel = df.loc[df['fuel'] == 'Diesel']
imax = Diesel['selling_price'].idxmax()
Diesel[imax:imax+1]
# Out:
#                          name  year  selling_price  km_driven    fuel  \
# 201  Chevrolet Beat Diesel LT  2012         150000      60000  Diesel
#
#     seller_type transmission        owner
# 201  Individual       Manual  First Owner

# %% [markdown]
# 28. Menampilkan mobil berbahan bakar Diesel dengan harga termurah

# %%
# Menampilkan mobil berbahan bakar Diesel dengan harga termurah
imin = Diesel['selling_price'].idxmin()
Diesel[imin:imin+1]
# Out:
#                       name  year  selling_price  km_driven    fuel  \
# 3657  Chevrolet Captiva LT  2009         500000     130000  Diesel
#
#      seller_type transmission        owner
# 3657  Individual       Manual  First Owner

# %% [markdown]
# 29. Menampilkan mobil berbahan bakar Petrol dengan harga termahal

# %%
# Menampilkan mobil berbahan bakar Petrol dengan harga termahal
Petrol = df.loc[df['fuel'] == 'Petrol']
imax = Petrol['selling_price'].max()
Petrol.loc[Petrol['selling_price'] == imax]
# Out:
#                                           name  year  selling_price  \
# 3872  Audi RS7 2015-2019 Sportback Performance  2016        8900000
#
#       km_driven    fuel seller_type transmission        owner
# 3872      13000  Petrol      Dealer    Automatic  First Owner

# %% [markdown]
# 30. Menampilkan mobil berbahan bakar Petrol dengan harga termurah

# %%
# Menampilkan mobil berbahan bakar Petrol dengan harga termurah
imin = Petrol['selling_price'].min()
Petrol.loc[Petrol['selling_price'] == imin]
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 2662  Ford Ikon 1.6 ZXI NXt  2005          20000      25000  Petrol
#
#      seller_type transmission         owner
# 2662  Individual       Manual  Second Owner

# %% [markdown]
# 31. Menampilkan mobil berbahan bakar CNG termahal

# %%
# Menampilkan mobil berbahan bakar CNG termahal
CNG = df.loc[df['fuel'] == 'CNG']
imax = CNG['selling_price'].max()
CNG.loc[CNG['selling_price'] == imax]
# Out:
#                        name  year  selling_price  km_driven fuel seller_type  \
# 4076  Maruti Ertiga VXI CNG  2014         595000      56600  CNG      Dealer
#
#      transmission        owner
# 4076       Manual  First Owner

# %% [markdown]
# 32. Menampilkan mobil berbahan bakar CNG termurah

# %%
# Menampilkan mobil berbahan bakar CNG termurah
imin = CNG['selling_price'].min()
CNG.loc[CNG['selling_price'] == imin]
# Out:
#                  name  year  selling_price  km_driven fuel seller_type  \
# 3014  Maruti Omni CNG  2007          45000     100000  CNG  Individual
#
#      transmission                 owner
# 3014       Manual  Fourth & Above Owner

# %% [markdown]
# 33. Menampilkan mobil berbahan bakar LPG termahal

# %%
# Menampilkan mobil berbahan bakar LPG termahal
LPG = df.loc[df['fuel'] == 'LPG']
imax = LPG['selling_price'].max()
LPG.loc[LPG['selling_price'] == imax]
# Out:
#                        name  year  selling_price  km_driven fuel seller_type  \
# 1435  Hyundai i10 Magna LPG  2014         290000      29000  LPG  Individual
#
#      transmission        owner
# 1435       Manual  First Owner

# %% [markdown]
# 34. Menampilkan mobil berbahan bakar LPG termurah

# %%
# Menampilkan mobil berbahan bakar LPG termurah
imin = LPG['selling_price'].min()
LPG.loc[LPG['selling_price'] == imin]
# Out:
#                            name  year  selling_price  km_driven fuel  \
# 1699  Maruti Omni 5 Str STD LPG  1998          50000      35000  LPG
#
#      seller_type transmission         owner
# 1699  Individual       Manual  Second Owner

# %% [markdown]
# 35. Menampilkan mobil elektrik termahal dan termurah

# %%
# Menampilkan mobil elektrik termahal dan termurah
df.loc[df['fuel'] == 'Electric']
# Out:
#                      name  year  selling_price  km_driven      fuel  \
# 4145  Toyota Camry Hybrid  2006         310000      62000  Electric
#
#      seller_type transmission         owner
# 4145      Dealer    Automatic  Second Owner

# %% [markdown]
# 36. Menampilkan koefisien relasi antara tahun dengan jarak tempuh mobil

# %%
# Menampilkan koefisien relasi antara tahun dengan jarak tempuh mobil
df['year'].corr(df['km_driven'])
# Out:
# -0.4196881460829124

# %% [markdown]
# 37. Menampilkan koefisien relasi antara tahun dengan harga penjualan

# %%
# Menampilkan koefisien relasi antara tahun dengan harga penjualan
df['year'].corr(df['selling_price'])
# Out:
# 0.41392167981085576

# %% [markdown]
# 38. Menampilkan koefisien relasi antara harga penjualan dengan jarak tempuh mobil

# %%
# Menampilkan koefisien relasi antara harga penjualan dengan jarak tempuh mobil
df['selling_price'].corr(df['km_driven'])
# Out:
# -0.1922886305451143
